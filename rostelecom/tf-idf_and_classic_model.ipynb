# %% [markdown]
# # 2. TF-IDF + classic model

# %% [markdown]
# Попробуем закодировать текстовые ответы в числовые векторы. В новом латентном пространстве построим классическую модель машинного обучения (KNN, LogReg, Naive Bayes).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0   для анализа массивов данных необходимых в работе     2.0
# 1  train_1  Буду использовать полученные знания в работе д...     2.0
# 2  train_2  хочу стать топовым программистом во всём мире ...     1.5
#
#                                              answer2  score2  \
# 0   для анализа массивов данных необходимых в работе     2.0
# 1  Автоматизирую процесс сбора данных и дальнейше...     2.0
# 2                            изучаю программирование     1.5
#
#                                              answer3  score3  result
# 0  стараюсь всегда брать задачи, выполнение котор...     2.0     6.0
# 1  Задача по анализу кода и содержанию пакетов - ...     1.5     5.5
# 2                                                  -     0.0     3.0

# %%
df.isna().sum()
# Out:
# id         0
# answer1    0
# score1     0
# answer2    1
# score2     0
# answer3    0
# score3     0
# result     0
# dtype: int64

# %%
df = df.fillna('')

# %%
def clear_text_data(frame):
    """Производит очистку текста от лишних сиволов (всего кроме букв и цифр)"""
    new_frame = frame.copy()
    for col in ['answer1', 'answer2', 'answer3']:
        new_frame[col] = new_frame[col].str.lower().str.replace('[^\w\s]', '', regex=True)
    return new_frame

# %%
def lemmatize_text(text):
    """Производит лемматизацию токенов в тексте"""
    words = text.split()  # Разбиваем текст на слова
    lemmas = [morph.parse(word)[0].normal_form for word in words]  # Получаем нормальную форму слова
    return ' '.join(lemmas)  # Объединяем леммы в строку

# %% [markdown]
# Произведем очистку текста от лишних символов и лемматизацию:

# %%
import pymorphy3
morph = pymorphy3.MorphAnalyzer() # для лемматизации

# %%
df = clear_text_data(df)
df.loc[:, ['answer1', 'answer2', 'answer3']] = df[['answer1', 'answer2', 'answer3']].map(lemmatize_text)

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score

# %%
def conf_matrix(y, y_pred):
    """Выводит матрицу ошибок"""
    cm = confusion_matrix(y, y_pred)
    plt.figure(figsize=(3, 2))
    sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu', xticklabels=['Класс 0', 'Класс 1'], yticklabels=['Класс 0', 'Класс 1'])
    plt.ylabel('Истиный класс')
    plt.xlabel('Предсказанный класс')
    plt.title('Матрица ошибок')
    plt.show()

# %%
from sklearn.model_selection import cross_val_predict

def get_best_threshold(model, X_train, y_train):
    """Ищет лучший порог отсечения, который максимизирует метрику f1_macro с использованием кросс-валидации"""
    # Получаем вероятности предсказаний с помощью кросс-валидации
    y_probs = cross_val_predict(model, X_train, y_train, cv=5, method='predict_proba')[:, 1]

    thresholds = np.arange(0.0, 1.0, 0.01)
    f1_scores = []
    
    for threshold in thresholds:
        y_pred = (y_probs >= threshold).astype(int)
        f1 = f1_score(y_train, y_pred, average='macro')
        f1_scores.append(f1)
    
    optimal_threshold = thresholds[np.argmax(f1_scores)]
    optimal_f1 = max(f1_scores)
    return optimal_threshold

# %% [markdown]
# ## 2.1. TF-IDF + KNN

# %%
# !pip install nltk

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords

from sklearn.model_selection import train_test_split

# %% [markdown]
# Будем использовать для векторизации TF-IDF:

# %%
nltk.download('stopwords') # загрузка стоп-слов
vectorizer = TfidfVectorizer(stop_words=stopwords.words('russian')) # векторизатор TF-IDF
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\matve\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 2.1.1. Пробная модель для первого ответа

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0

# %% [markdown]
# Разобьем данные на тренировочные (на которых будем обучаться), тестовые (на которых будем сравнивать разные модели) и новые неразмеченные данные (метки для которых нужно предсказать по заданию):

# %%
X, y = df[['answer1']].copy(), df['score1'].copy()
X['answer1_len'] = X['answer1'].map(len)     # добавляем информацию о длине ответа
y = (y > 1.5).astype(int)                    # сводим к классификации

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Векторизуем текстовую колонку:

# %%
lens_train = X_train['answer1_len'].to_numpy().reshape(-1, 1)
lens_test = X_test['answer1_len'].to_numpy().reshape(-1, 1)

X_train = np.hstack([vectorizer.fit_transform(X_train['answer1']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['answer1']).toarray(), lens_test])

# %%
X_train
# Out:
# array([[  0.,   0.,   0., ...,   0.,   0.,  70.],
#        [  0.,   0.,   0., ...,   0.,   0.,  32.],
#        [  0.,   0.,   0., ...,   0.,   0., 179.],
#        ...,
#        [  0.,   0.,   0., ...,   0.,   0.,  10.],
#        [  0.,   0.,   0., ...,   0.,   0.,  78.],
#        [  0.,   0.,   0., ...,   0.,   0., 352.]])

# %% [markdown]
# Обучим KNN-классификатор:

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(metric='cosine')
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine')

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.60      0.73       286
#            1       0.58      0.93      0.71       169
#
#     accuracy                           0.72       455
#    macro avg       0.76      0.77      0.72       455
# weighted avg       0.81      0.72      0.72       455
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.40      0.54       123
#            1       0.46      0.85      0.59        73
#
#     accuracy                           0.57       196
#    macro avg       0.64      0.62      0.56       196
# weighted avg       0.68      0.57      0.56       196

# %%
optimal_threshold = get_best_threshold(model, X_train, y_train)
y_test_pred = (model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.40      0.54       123
#            1       0.46      0.85      0.59        73
#
#     accuracy                           0.57       196
#    macro avg       0.64      0.62      0.56       196
# weighted avg       0.68      0.57      0.56       196

# %% [markdown]
# Подберем гиперпараметры с помощью Optuna:

# %%
# !pip install optuna

# %%
import optuna
import logging
from sklearn.model_selection import cross_val_score

optuna.logging.set_verbosity(optuna.logging.ERROR) # отключаем стандартный вывод optuna

# %%
def objective(trial):
    model = KNeighborsClassifier(
        n_neighbors=trial.suggest_int('n_neighbors', 1, 50),
        weights=trial.suggest_categorical('weights', ['uniform', 'distance']),
        metric=trial.suggest_categorical('metric', ['euclidean', 'cosine']),
        leaf_size=trial.suggest_int('leaf_size', 1, 100),
    )

    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    # Выводим логи
    print(f'Trial {trial.number+1}: score = {score}')
    
    return score


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)
# Out:
# Trial 1: score = 0.3580626384529948
# Trial 2: score = 0.44955510636242507
# Trial 3: score = 0.6236116129423216
# Trial 4: score = 0.42256967318140903
# Trial 5: score = 0.6411732708318918
# Trial 6: score = 0.3580626384529948
# Trial 7: score = 0.3998024907069565
# Trial 8: score = 0.6584432717223108
# Trial 9: score = 0.39184435193504713
# Trial 10: score = 0.6218853775414024
# Trial 11: score = 0.6419486107393881
# Trial 12: score = 0.6536091362712678
# Trial 13: score = 0.6495883512296473
# Trial 14: score = 0.6632920370238379
# Trial 15: score = 0.6075158312691707
# Trial 16: score = 0.6632920370238379
# Trial 17: score = 0.6184655531214567
# Trial 18: score = 0.630549391633806
# Trial 19: score = 0.5965813337695792
# Trial 20: score = 0.6514094956558059
# Trial 21: score = 0.6632920370238379
_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       286
#            1       1.00      0.99      1.00       169
#
#     accuracy                           1.00       455
#    macro avg       1.00      1.00      1.00       455
# weighted avg       1.00      1.00      1.00       455
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78       123
#            1       0.63      0.59      0.61        73
#
#     accuracy                           0.72       196
#    macro avg       0.70      0.69      0.70       196
# weighted avg       0.72      0.72      0.72       196

# %%
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# %%
optimal_threshold
# Out:
# 0.51

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       123
#            1       0.63      0.56      0.59        73
#
#     accuracy                           0.71       196
#    macro avg       0.69      0.68      0.69       196
# weighted avg       0.71      0.71      0.71       196

# %% [markdown]
# Модель сильно переобучилась, но показала метрики выше, чем без подбора.

# %% [markdown]
# ## 2.1.2. По модели на каждый ответ

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# Построим `N` моделей отдельно на каждый из ответов.

# %%
N = 3

# %%
for i in range(N):
    df[f'answer{i+1}_len'] = df[f'answer{i+1}'].map(len)

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result  \
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0
#
#    answer1_len  answer2_len  answer3_len
# 0           45           45          538
# 1          136          110          304
# 2           59           24            0

# %%
X_df, y_df = df.drop(columns=['id', 'result', 'score1', 'score2', 'score3']), df[['score1', 'score2', 'score3']]

# %%
X_df.head(3)
# Out:
#                                              answer1  \
# 0      для анализ массив данные необходимый в работа
# 1  быть использовать получить знание в работа для...
# 2  хотеть стать топовый программист в весь мир но...
#
#                                              answer2  \
# 0      для анализ массив данные необходимый в работа
# 1  автоматизировать процесс сбор данные и дальней...
# 2                           изучать программирование
#
#                                              answer3  answer1_len  \
# 0  стараться всегда брать задача выполнение котор...           45
# 1  задача по анализ код и содержание пакет выясня...          136
# 2                                                              59
#
#    answer2_len  answer3_len
# 0           45          538
# 1          110          304
# 2           24            0

# %%
y_df.head(3)
# Out:
#    score1  score2  score3
# 0     2.0     2.0     2.0
# 1     2.0     2.0     1.5
# 2     1.5     1.5     0.0

# %%
y_df = (y_df > 1.5).astype(int) # сводим к меткам классов

# %%
def train_model(X_train, X_test, y_train, y_test, y_test_cont):
    """Обучение модели для предсказания оценки для ответа на котнкретный вопрос"""
    def objective(trial): 
        model = KNeighborsClassifier(
            n_neighbors=trial.suggest_int('n_neighbors', 1, 50),
            weights=trial.suggest_categorical('weights', ['uniform', 'distance']),
            metric=trial.suggest_categorical('metric', ['euclidean', 'cosine']),
            leaf_size=trial.suggest_int('leaf_size', 1, 100),
        )
        
        # Обучение модели
        model.fit(X_train, y_train)
        
        # Оцениваем модель с помощью кросс-валидации
        return cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()
    
    sampler = optuna.samplers.RandomSampler(seed=42)
    study = optuna.create_study(sampler=sampler, direction='maximize')
    study.optimize(objective, n_trials=300)

    # Обучение модели с лучшими гиперпараметрами
    best_model = KNeighborsClassifier(**study.best_params)
    best_model.fit(X_train, y_train)
    
    y_test_pred = best_model.predict(X_test)

    # Выбираем оптимальный порог отсечения
    optimal_threshold = get_best_threshold(best_model, X_train, y_train)
    y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

    # Считаем регрессионную метрику
    reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 3)

    # Выводим метрики
    print(f'Answer {i+1}:')
    print(classification_report(y_test, y_test_pred))
    print(f'MAE = {reg_score}')

    return y_test_pred

# %%
predictions = pd.DataFrame() # датафрейм с предсказаниями для ответов в каждой колонке

for i in range(N):
    cols = [f'answer{i+1}', f'answer{i+1}_len']

    # Выбираем ответ на конкретный вопрос
    X_df_tmp, y_df_tmp = X_df[cols], y_df[f'score{i+1}']
    X_train, X_test, y_train, y_test = train_test_split(X_df_tmp, y_df_tmp, stratify=y_df_tmp, test_size=0.3, random_state=42)

    # Производим векторизацию
    lens_train = X_train[f'answer{i+1}_len'].to_numpy().reshape(-1, 1) # сохраняем столбец с весами, чтобы добавить его к признакам
    lens_test = X_test[f'answer{i+1}_len'].to_numpy().reshape(-1, 1)
    X_train = np.hstack([vectorizer.fit_transform(X_train[f'answer{i+1}']).toarray(), lens_train]) # векторизация и склеивание со столбцом длин
    X_test = np.hstack([vectorizer.transform(X_test[f'answer{i+1}']).toarray(), lens_test])

    # непрерывные таргеты для регрессионной оценки
    y_test_cont = df.iloc[y_test.index][f'score{i+1}']

    y_pred = train_model(X_train, X_test, y_train, y_test, y_test_cont)
    predictions[f'pred_score{i+1}'] = y_pred
# Out:
# Answer 1:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       123
#            1       0.63      0.56      0.59        73
#
#     accuracy                           0.71       196
#    macro avg       0.69      0.68      0.69       196
# weighted avg       0.71      0.71      0.71       196
#
# MAE = 0.7402220276502319
# Answer 2:
#               precision    recall  f1-score   support
#
#            0       0.72      0.55      0.62        87
#            1       0.70      0.83      0.76       109
#
#     accuracy                           0.70       196
#    macro avg       0.71      0.69      0.69       196
# weighted avg       0.71      0.70      0.70       196
#
# MAE = 0.6730528946272387
# Answer 3:
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.81        83
#            1       0.84      0.89      0.87       113
#
#     accuracy                           0.84       196
#    macro avg       0.84      0.83      0.84       196
# weighted avg       0.84      0.84      0.84       196
#
# MAE = 0.5593317972350229

# %%
(0.69 + 0.69 + 0.84) / 3   # avg f1_macro
# Out:
# 0.7399999999999999

# %%
(0.74 + 0.67 + 0.56) / 3   # avg MAE
# Out:
# 0.6566666666666667

# %% [markdown]
# Классификация на нескольких KNN дает, в общем-то, такие же результаты как и аналогичная на CatBoost.

# %% [markdown]
# ## 2.1.3. Одна модель на все ответы

# %% [markdown]
# Также объединим все ответы в один большой и будем классифицировать их одной KNN-моделью.

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result  \
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0
#
#    answer1_len  answer2_len  answer3_len
# 0           45           45          538
# 1          136          110          304
# 2           59           24            0

# %%
df['general_answer'] = df['answer1'] + ' ' + df['answer2'] + ' ' + df['answer3']

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result  \
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0
#
#    answer1_len  answer2_len  answer3_len  \
# 0           45           45          538
# 1          136          110          304
# 2           59           24            0
#
#                                       general_answer
# 0  для анализ массив данные необходимый в работа ...
# 1  быть использовать получить знание в работа для...
# 2  хотеть стать топовый программист в весь мир но...

# %%
X, y = df[['general_answer', 'answer1_len', 'answer2_len', 'answer3_len']], df['result']
y = (y >= 6).astype(int)  # сводим к классификации

# %%
X.head(3)
# Out:
#                                       general_answer  answer1_len  \
# 0  для анализ массив данные необходимый в работа ...           45
# 1  быть использовать получить знание в работа для...          136
# 2  хотеть стать топовый программист в весь мир но...           59
#
#    answer2_len  answer3_len
# 0           45          538
# 1          110          304
# 2           24            0

# %%
y.value_counts()
# Out:
# result
# 0    420
# 1    231
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
X_train.head(3)
# Out:
#                                         general_answer  answer1_len  \
# 482  я хотеть повысить уровень свой знание и навык ...           62
# 27   мой компания развиваться и я хотеть развиватьс...          290
# 430  хотеть освоить pyton когдато изучать ассемблер...          101
#
#      answer2_len  answer3_len
# 482          124          226
# 27           181          400
# 430           70          328

# %% [markdown]
# Векторизуем и добавляем признаки с длинами ответов:

# %%
# считаем длины ответов и переводим в массив numpy
lens_train = X_train[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()
lens_test = X_test[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()

# векторизуем и склеиваем с признаками длины
X_train = np.hstack([vectorizer.fit_transform(X_train['general_answer']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['general_answer']).toarray(), lens_test])

# %%
def objective(trial): 
    model = KNeighborsClassifier(
        n_neighbors=trial.suggest_int('n_neighbors', 1, 50),
        weights=trial.suggest_categorical('weights', ['uniform', 'distance']),
        metric=trial.suggest_categorical('metric', ['euclidean', 'cosine']),
        leaf_size=trial.suggest_int('leaf_size', 1, 100),
    )
    
    # Обучение модели и оценка на валидационном наборе
    model.fit(X_train, y_train)
    
    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    # Вывод логов
    print(f'Trial {trial.number+1}: score = {score}')
    
    return score

sampler = optuna.samplers.RandomSampler(seed=42)
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# Trial 1: score = 0.6557042084239993
# Trial 2: score = 0.5991623633736715
# Trial 3: score = 0.42615177628637896
# Trial 4: score = 0.5760198388704156
# Trial 5: score = 0.5149221830979022
# Trial 6: score = 0.476085817520694
# Trial 7: score = 0.6498810063170302
# Trial 8: score = 0.5495607029672864
# Trial 9: score = 0.5662331411180423
# Trial 10: score = 0.6166509751934788
# Trial 11: score = 0.6382214399581645
# Trial 12: score = 0.5745879277377582
# Trial 13: score = 0.5615823198236741
# Trial 14: score = 0.6512758431636845
# Trial 15: score = 0.5566240426312274
# Trial 16: score = 0.5682794929016459
# Trial 17: score = 0.64824998909946
# Trial 18: score = 0.5566240426312274
# Trial 19: score = 0.5549175878548642
# Trial 20: score = 0.4744325751250056
# Trial 21: score = 0.4355391665881892
# Trial 22: score = 0.6451166511066848
# Trial 23: score = 0.5682794929016459
# Trial 24: score = 0.5316655194437635
# Trial 25: score = 0.6513845010638859
# Trial 26: score = 0.4240072929094282
# Trial 27: score = 0.6297106153522718
# Trial 28: score = 0.6209416343081412
# Trial 29: score = 0.5583044733378733
# Trial 30: score = 0.5607563782905631
# Trial 31: score = 0.6512758431636845
# Trial 32: score = 0.6451166511066848
# Trial 33: score = 0.4240072929094282
# Trial 34: score = 0.4420288675796131
# Trial 35: score = 0.6508202655066351
# Trial 36: score = 0.4794429192750426
# Trial 37: score = 0.669813916725827
# Trial 38: score = 0.5348723331430894
# Trial 39: score = 0.5727043566997339
# Trial 40: score = 0.4974026485732154
# Trial 41: score = 0.6277559231571274
# Trial 42: score = 0.6300794009337262
# Trial 43: score = 0.4376441381504062
# Trial 44: score = 0.6366931446800294
# Trial 45: score = 0.6286216592889327
# Trial 46: score = 0.6514940748748825
# Trial 47: score = 0.5654052215871281
# Trial 48: score = 0.5632846045034899
# Trial 49: score = 0.5243125722320506
# Trial 50: score = 0.5621433590994069
# Trial 51: score = 0.5583044733378733
# Trial 52: score = 0.5694001477124832
# Trial 53: score = 0.5495607029672864
# Trial 54: score = 0.6127057619958902
# Trial 55: score = 0.6277559231571274
# Trial 56: score = 0.6358864656544427
# Trial 57: score = 0.4376441381504062
# Trial 58: score = 0.5103090937249297
# Trial 59: score = 0.6557042084239993
# Trial 60: score = 0.4852936002522646
# Trial 61: score = 0.49865899307403555
# Trial 62: score = 0.44811408449639306
# Trial 63: score = 0.5348723331430894
# Trial 64: score = 0.6451166511066848
# Trial 65: score = 0.441985280264772
# Trial 66: score = 0.6360294550353073
# Trial 67: score = 0.6553811517493825
# Trial 68: score = 0.6335741115663093
# Trial 69: score = 0.5687878120914599
# Trial 70: score = 0.4744325751250056
# Trial 71: score = 0.6413716065549614
# Trial 72: score = 0.5149221830979022
# Trial 73: score = 0.6273172586455573
# Trial 74: score = 0.6491991694134182
# Trial 75: score = 0.6514940748748825
# Trial 76: score = 0.653654761447573
# Trial 77: score = 0.6002409987903506
# Trial 78: score = 0.6554373014713145
# Trial 79: score = 0.6240963890158805
# Trial 80: score = 0.491753053801364
# Trial 81: score = 0.6209416343081412
# Trial 82: score = 0.5972725029104764
# Trial 83: score = 0.555954027092757
# Trial 84: score = 0.6542427337566573
# Trial 85: score = 0.5569995638468999
# Trial 86: score = 0.6508202655066351
# Trial 87: score = 0.5632846045034899
# Trial 88: score = 0.6542427337566573
# Trial 89: score = 0.5991623633736715
# Trial 90: score = 0.45030299611125973
# Trial 91: score = 0.6277559231571274
# Trial 92: score = 0.5712100949285306
# Trial 93: score = 0.6522681566634899
# Trial 94: score = 0.6554373014713145
# Trial 95: score = 0.4890543508559981
# Trial 96: score = 0.4901645975543225
# Trial 97: score = 0.48982748568227663
# Trial 98: score = 0.6473111865493222
# Trial 99: score = 0.6145115944832982
# Trial 100: score = 0.5727043566997339

# %%
y_test_cont = df.iloc[y_test.index]['result']   # для регрессионной модели
y_test_cont
# Out:
# 322    1.0
# 443    6.0
# 466    6.0
# 444    9.0
# 156    9.0
#       ...
# 151    3.5
# 192    6.0
# 223    3.0
# 327    6.5
# 600    1.0
# Name: result, Length: 196, dtype: float64

# %%
# Обучение модели с лучшими гиперпараметрами
best_model = KNeighborsClassifier(**study.best_params)
best_model.fit(X_train, y_train)

# Делаем предсказания для трейна и теста
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# Выбираем оптимальный порог отсечения и делаем новые предсказания для теста
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# Регрессионная оценка
reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 9)

# %%
print(classification_report(y_test, y_test_pred))
print(f'MAE = {reg_score}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74       126
#            1       0.54      0.54      0.54        70
#
#     accuracy                           0.67       196
#    macro avg       0.64      0.64      0.64       196
# weighted avg       0.67      0.67      0.67       196
#
# MAE = 2.078481392557023

# %% [markdown]
# Получается, что в среднем MAE-ошибка для каждого ответа равна:

# %%
2.08 / 3
# Out:
# 0.6933333333333334

# %% [markdown]
# Можно попробовать задать разные веса классам, потому что присутствует дисбаланс:

# %%
y.value_counts()
# Out:
# result
# 0    420
# 1    231
# Name: count, dtype: int64

# %%
409 / 242
# Out:
# 1.6900826446280992

# %%
# здесь должен быть код

# %% [markdown]
# Эта модель также немного проигрывает аналогичной на CatBoost (`f1_macro: 0.67 vs 0.64`).

# %% [markdown]
# ## 2.2. TF-IDF + LogReg

# %% [markdown]
# ### 2.2.1. Пробная модель для первого ответа

# %%
from sklearn.linear_model import LogisticRegression

# %%
df.head(3)
# Out:
#         id                                            answer1  score1  \
# 0  train_0      для анализ массив данные необходимый в работа     2.0
# 1  train_1  быть использовать получить знание в работа для...     2.0
# 2  train_2  хотеть стать топовый программист в весь мир но...     1.5
#
#                                              answer2  score2  \
# 0      для анализ массив данные необходимый в работа     2.0
# 1  автоматизировать процесс сбор данные и дальней...     2.0
# 2                           изучать программирование     1.5
#
#                                              answer3  score3  result  \
# 0  стараться всегда брать задача выполнение котор...     2.0     6.0
# 1  задача по анализ код и содержание пакет выясня...     1.5     5.5
# 2                                                        0.0     3.0
#
#    answer1_len  answer2_len  answer3_len  \
# 0           45           45          538
# 1          136          110          304
# 2           59           24            0
#
#                                       general_answer
# 0  для анализ массив данные необходимый в работа ...
# 1  быть использовать получить знание в работа для...
# 2  хотеть стать топовый программист в весь мир но...

# %%
X, y = df[['answer1']].copy(), df['score1'].copy()
X['answer1_len'] = X['answer1'].map(len)     # добавляем информацию о длине ответа
y = (y > 1.5).astype(int)                    # сводим к классификации

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Векторизуем текстовую колонку:

# %%
lens_train = X_train['answer1_len'].to_numpy().reshape(-1, 1)
lens_test = X_test['answer1_len'].to_numpy().reshape(-1, 1)

X_train = np.hstack([vectorizer.fit_transform(X_train['answer1']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['answer1']).toarray(), lens_test])

# %%
y.value_counts()
# Out:
# score1
# 0    409
# 1    242
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88       286
#            1       0.90      0.64      0.75       169
#
#     accuracy                           0.84       455
#    macro avg       0.86      0.80      0.81       455
# weighted avg       0.85      0.84      0.83       455
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       123
#            1       0.71      0.53      0.61        73
#
#     accuracy                           0.74       196
#    macro avg       0.73      0.70      0.71       196
# weighted avg       0.74      0.74      0.74       196

# %%
optimal_threshold = get_best_threshold(model, X_train, y_train)
y_test_pred = (model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.65      0.74       123
#            1       0.58      0.81      0.67        73
#
#     accuracy                           0.71       196
#    macro avg       0.71      0.73      0.71       196
# weighted avg       0.75      0.71      0.71       196

# %% [markdown]
# Для модели без параметров очень неплохие результаты.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
# считаем длины ответов и переводим в массив numpy
lens_train = X_train[['answer1_len']].to_numpy()
lens_test = X_test[['answer1_len']].to_numpy()

# векторизуем и склеиваем с признаками длины
X_train = np.hstack([vectorizer.fit_transform(X_train['answer1']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['answer1']).toarray(), lens_test])

# %%
def objective(trial): 
    model = LogisticRegression(
        C=trial.suggest_float('C', 1e-4, 1e4, log=True),
        penalty=trial.suggest_categorical('penalty', ['l1', 'l2']),
        class_weight=trial.suggest_categorical('class_weight', [None, 'balanced']),
        solver='liblinear'
    )
    
    # Обучение модели и оценка на валидационном наборе
    model.fit(X_train, y_train)
    
    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    #
# Trial 80: score = 0.6438905131610217
# Trial 81: score = 0.2747127919911012
# Trial 82: score = 0.6607893964418915
# Trial 83: score = 0.7064395214916923
# Trial 84: score = 0.709685738170983
# Trial 85: score = 0.6617740110230091
# Trial 86: score = 0.6884241848353744
# Trial 87: score = 0.2747127919911012
# Trial 88: score = 0.680695274702438
# Trial 89: score = 0.2747127919911012
# Trial 90: score = 0.6635349559759629
# Trial 91: score = 0.6616497470245242
# Trial 92: score = 0.7042249908017035
# Trial 93: score = 0.29008655203529465
# Trial 94: score = 0.6879352575472022
# Trial 95: score = 0.3859604571013967
# Trial 96: score = 0.6695277739769083
# Trial 97: score = 0.6749155841063755
# Trial 98: score = 0.6743362441386539
# Trial 99: score = 0.6953301847515355
# Trial 100: score = 0.6931939431939433

# %%
best_model = LogisticRegression(**study.best_params, solver='liblinear')
best_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0283249130221837, class_weight='balanced', penalty='l1',
#                    solver='liblinear')

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88       286
#            1       0.90      0.64      0.75       169
#
#     accuracy                           0.84       455
#    macro avg       0.86      0.80      0.81       455
# weighted avg       0.85      0.84      0.83       455
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       123
#            1       0.71      0.53      0.61        73
#
#     accuracy                           0.74       196
#    macro avg       0.73      0.70      0.71       196
# weighted avg       0.74      0.74      0.74       196

# %%
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)
optimal_threshold
# Out:
# 0.52

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.72      0.78       123
#            1       0.62      0.79      0.70        73
#
#     accuracy                           0.74       196
#    macro avg       0.74      0.75      0.74       196
# weighted avg       0.77      0.74      0.75       196

# %% [markdown]
# ### 2.2.2. По модели на каждый ответ

# %%
X_df.head(1)
# Out:
#                                          answer1  \
# 0  для анализ массив данные необходимый в работа
#
#                                          answer2  \
# 0  для анализ массив данные необходимый в работа
#
#                                              answer3  answer1_len  \
# 0  стараться всегда брать задача выполнение котор...           45
#
#    answer2_len  answer3_len
# 0           45          538

# %%
X_df, y_df = df.drop(columns=['id', 'result', 'score1', 'score2', 'score3']), df[['score1', 'score2', 'score3']]
y_df = (y_df > 1.5).astype(int) # сводим к меткам классов

# %%
def train_model(X_train, X_test, y_train, y_test, y_test_cont):
    """Обучение модели для предсказания оценки для ответа на котнкретный вопрос"""
    def objective(trial): 
        model = LogisticRegression(
            C=trial.suggest_float('C', 1e-4, 1e4, log=True),
            penalty=trial.suggest_categorical('penalty', ['l1', 'l2']),
            class_weight=trial.suggest_categorical('class_weight', [None, 'balanced']),
            solver='liblinear'
        )
        
        # Обучение модели
        model.fit(X_train, y_train)
        
        # Оцениваем модель с помощью кросс-валидации
        return cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()
    
    sampler = optuna.samplers.RandomSampler(seed=42)
    study = optuna.create_study(sampler=sampler, direction='maximize')
    study.optimize(objective, n_trials=300)

    # Обучение модели с лучшими гиперпараметрами
    best_model = LogisticRegression(**study.best_params, solver='liblinear')
    best_model.fit(X_train, y_train)

    # Выбираем оптимальный порог отсечения
    optimal_threshold = get_best_threshold(best_model, X_train, y_train)
    y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

    # Считаем регрессионную метрику
    reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 3)

    # Выводим метрики
    print(f'Answer {i+1}:')
    print(classification_report(y_test, y_test_pred))
    print(f'MAE = {reg_score}')

    return y_test_pred

# %%
predictions = pd.DataFrame() # датафрейм с предсказаниями для ответов в каждой колонке

for i in range(N):
    cols = [f'answer{i+1}', f'answer{i+1}_len']

    # Выбираем ответ на конкретный вопрос
    X_df_tmp, y_df_tmp = X_df[cols], y_df[f'score{i+1}']
    X_train, X_test, y_train, y_test = train_test_split(X_df_tmp, y_df_tmp, stratify=y_df_tmp, test_size=0.3, random_state=42)

    # Производим векторизацию
    lens_train = X_train[f'answer{i+1}_len'].to_numpy().reshape(-1, 1) # сохраняем столбец с весами, чтобы добавить его к признакам
    lens_test = X_test[f'answer{i+1}_len'].to_numpy().reshape(-1, 1)
    X_train = np.hstack([vectorizer.fit_transform(X_train[f'answer{i+1}']).toarray(), lens_train]) # векторизация и склеивание со столбцом длин
    X_test = np.hstack([vectorizer.transform(X_test[f'answer{i+1}']).toarray(), lens_test])
    
    # непрерывные таргеты для регрессионной оценки
    y_test_cont = df.iloc[y_test.index][f'score{i+1}']

    y_pred = train_model(X_train, X_test, y_train, y_test, y_test_cont)
    predictions[f'pred_score{i+1}'] = y_pred
# Out:
# Answer 1:
#               precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79       123
#            1       0.64      0.84      0.72        73
#
#     accuracy                           0.76       196
#    macro avg       0.76      0.78      0.76       196
# weighted avg       0.79      0.76      0.76       196
#
# MAE = 0.5167121542279779
# Answer 2:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75        87
#            1       0.84      0.71      0.77       109
#
#     accuracy                           0.76       196
#    macro avg       0.76      0.77      0.76       196
# weighted avg       0.77      0.76      0.76       196
#
# MAE = 0.6355899792838606
# Answer 3:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        83
#            1       0.86      0.86      0.86       113
#
#     accuracy                           0.84       196
#    macro avg       0.83      0.83      0.83       196
# weighted avg       0.84      0.84      0.84       196
#
# MAE = 0.5544145056593813

# %%
(0.76 + 0.76 + 0.83) / 3   # avg f1_macro
# Out:
# 0.7833333333333333

# %%
(0.52 + 0.64 + 0.55) / 3   # avg MAE
# Out:
# 0.5700000000000001

# %% [markdown]
# Несколько моделей логрегрессии превзошли по показателям несколько классификаторов CatBoost (`f1_macro avg: 0.78 vs 0.74`)

# %% [markdown]
# ### 2.2.3. Одна модель на все ответы

# %%
X, y = df[['general_answer', 'answer1_len', 'answer2_len', 'answer3_len']], df['result']
y = (y >= 6).astype(int)  # сводим к классификации

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Векторизуем и добавляем признаки с длинами ответов:

# %%
# считаем длины ответов и переводим в массив numpy
lens_train = X_train[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()
lens_test = X_test[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()

# векторизуем и склеиваем с признаками длины
X_train = np.hstack([vectorizer.fit_transform(X_train['general_answer']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['general_answer']).toarray(), lens_test])

# %%
def objective(trial): 
    model = LogisticRegression(
        C=trial.suggest_float('C', 1e-4, 1e4, log=True),
        penalty=trial.suggest_categorical('penalty', ['l1', 'l2']),
        class_weight=trial.suggest_categorical('class_weight', [None, 'balanced']),
        solver='liblinear'
    )
    
    # Обучение модели
    model.fit(X_train, y_train)
    
    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    # Выводим логи
    print(f'Trial {trial.number+1}: score = {score}')

    return score
    
sampler = optuna.samplers.RandomSampler(seed=42)
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials
# Trial 83: score = 0.6940086093468805
# Trial 84: score = 0.6957819680016385
# Trial 85: score = 0.6510733492844334
# Trial 86: score = 0.6704981002887671
# Trial 87: score = 0.28611900800863344
# Trial 88: score = 0.675834833207469
# Trial 89: score = 0.2823591786070607
# Trial 90: score = 0.6699987282857969
# Trial 91: score = 0.649042509276969
# Trial 92: score = 0.7142280762994068
# Trial 93: score = 0.2872907596936344
# Trial 94: score = 0.7050599398651275
# Trial 95: score = 0.3925190156599553
# Trial 96: score = 0.6815828575443517
# Trial 97: score = 0.645199313764184
# Trial 98: score = 0.6804413998841671
# Trial 99: score = 0.6849600434679666
# Trial 100: score = 0.6926055621924443

# %%
y_test_cont = df.iloc[y_test.index]['result']   # для регрессионной модели
y_test_cont
# Out:
# 322    1.0
# 443    6.0
# 466    6.0
# 444    9.0
# 156    9.0
#       ...
# 151    3.5
# 192    6.0
# 223    3.0
# 327    6.5
# 600    1.0
# Name: result, Length: 196, dtype: float64

# %%
# Обучение модели с лучшими гиперпараметрами
best_model = LogisticRegression(**study.best_params, solver='liblinear')
best_model.fit(X_train, y_train)

# Делаем предсказания для трейна и теста
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# Выбираем оптимальный порог отсечения и делаем новые предсказания для теста
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# Регрессионная оценка
reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 9)

# %%
print(classification_report(y_test, y_test_pred))
print(f'MAE = {reg_score}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       126
#            1       0.66      0.64      0.65        70
#
#     accuracy                           0.76       196
#    macro avg       0.73      0.73      0.73       196
# weighted avg       0.75      0.76      0.75       196
#
# MAE = 1.7704605835913003

# %% [markdown]
# Получается в среднем на ответ регрессионная ошибка MAE равна:

# %%
1.77 / 3
# Out:
# 0.59

# %% [markdown]
# А это пока лучший результат среди всех вариантов "одной большой модели", но все же он проигрывает подходу с несколькими моделями для каждого ответа.

# %% [markdown]
# ## 2.3. TF-IDF + Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### 2.3.1. Пробная модель для первого ответа

# %%
X, y = df[['answer1']].copy(), df['score1'].copy()
X['answer1_len'] = X['answer1'].map(len)     # добавляем информацию о длине ответа
y = (y > 1.5).astype(int)                    # сводим к классификации

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Векторизуем текстовую колонку:

# %%
lens_train = X_train['answer1_len'].to_numpy().reshape(-1, 1)
lens_test = X_test['answer1_len'].to_numpy().reshape(-1, 1)

X_train = np.hstack([vectorizer.fit_transform(X_train['answer1']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['answer1']).toarray(), lens_test])

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
optimal_threshold = get_best_threshold(model, X_train, y_train)
y_test_pred = (model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80       123
#            1       0.69      0.55      0.61        73
#
#     accuracy                           0.74       196
#    macro avg       0.73      0.70      0.71       196
# weighted avg       0.73      0.74      0.73       196

# %% [markdown]
# Подберем гиперпараметры через Optuna:

# %%
y_train.value_counts(normalize=True) # для того, чтобы узнать априорные вероятности классов
# Out:
# score1
# 0    0.628571
# 1    0.371429
# Name: proportion, dtype: float64

# %%
def objective(trial): 
    model = MultinomialNB(
        alpha=trial.suggest_float('alpha', 1e-5, 10, log=True),
        fit_prior=trial.suggest_categorical('fit_prior', [True, False]),
        class_prior=[0.6, 0.4]
    )
    
    # Обучение модели и оценка на валидационном наборе
    model.fit(X_train, y_train)
    
    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    #
# Trial 242: score = 0.7052282568511318
# Trial 243: score = 0.6578726929308185
# Trial 244: score = 0.6578726929308185
# Trial 245: score = 0.6940510025330922
# Trial 246: score = 0.5978309971313569
# Trial 247: score = 0.668034588923127
# Trial 248: score = 0.6604402698535358
# Trial 249: score = 0.6604402698535358
# Trial 250: score = 0.6779122303505777
# Trial 251: score = 0.6578726929308185
# Trial 252: score = 0.6604402698535358
# Trial 253: score = 0.687893354932615
# Trial 254: score = 0.699016972009076
# Trial 255: score = 0.6604402698535358
# Trial 256: score = 0.6763173659705339
# Trial 257: score = 0.6604402698535358
# Trial 258: score = 0.6609474708702986
# Trial 259: score = 0.70205242762708
# Trial 260: score = 0.7106394674086582
# Trial 261: score = 0.7017951710855826
# Trial 262: score = 0.6604402698535358
# Trial 263: score = 0.6783127164517999
# Trial 264: score = 0.37898303700476677
# Trial 265: score = 0.6766495268088335
# Trial 266: score = 0.6038740067661361
# Trial 267: score = 0.7017951710855826
# Trial 268: score = 0.6578726929308185
# Trial 269: score = 0.668034588923127
# Trial 270: score = 0.44566068787048635
# Trial 271: score = 0.3052446544493256
# Trial 272: score = 0.4731204255069203
# Trial 273: score = 0.6783127164517999
# Trial 274: score = 0.6604402698535358
# Trial 275: score = 0.6604402698535358
# Trial 276: score = 0.4759853175619533
# Trial 277: score = 0.7073202230628164
# Trial 278: score = 0.6632482641368022
# Trial 279: score = 0.6766495268088335
# Trial 280: score = 0.6633036987974732
# Trial 281: score = 0.6578726929308185
# Trial 282: score = 0.34830391366470415
# Trial 283: score = 0.6578726929308185
# Trial 284: score = 0.6783127164517999
# Trial 285: score = 0.6578726929308185
# Trial 286: score = 0.6578726929308185
# Trial 287: score = 0.6750918458013894
# Trial 288: score = 0.6632482641368022
# Trial 289: score = 0.6652906764293107
# Trial 290: score = 0.6578726929308185
# Trial 291: score = 0.6633036987974732
# Trial 292: score = 0.6652906764293107
# Trial 293: score = 0.7100224402009399
# Trial 294: score = 0.6604402698535358
# Trial 295: score = 0.6578726929308185
# Trial 296: score = 0.6578726929308185
# Trial 297: score = 0.6578726929308185
# Trial 298: score = 0.636673700896639
# Trial 299: score = 0.6946750835275253
# Trial 300: score = 0.5353258506374396

# %%
study.best_params
# Out:
# {'alpha': 0.2366154006460316, 'fit_prior': True}

# %%
best_model = MultinomialNB(**study.best_params, class_prior=[0.6, 0.4])
best_model.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=0.2366154006460316, class_prior=[0.6, 0.4])

# %%
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)
optimal_threshold
# Out:
# 0.52

# %%
print(classification_report(y_train, y_train_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66       286
#            1       0.44      0.46      0.45       169
#
#     accuracy                           0.58       455
#    macro avg       0.55      0.56      0.56       455
# weighted avg       0.58      0.58      0.58       455
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       123
#            1       0.64      0.74      0.69        73
#
#     accuracy                           0.75       196
#    macro avg       0.74      0.75      0.74       196
# weighted avg       0.76      0.75      0.75       196

# %% [markdown]
# ### 2.3.2. По модели на каждый ответ

# %%
X_df, y_df = df.drop(columns=['id', 'result', 'score1', 'score2', 'score3']), df[['score1', 'score2', 'score3']]
y_df = (y_df > 1.5).astype(int) # сводим к меткам классов

# %%
def train_model(X_train, X_test, y_train, y_test, y_test_cont):
    """Обучение модели для предсказания оценки для ответа на котнкретный вопрос"""
    def objective(trial): 
        model = MultinomialNB(
            alpha=trial.suggest_float('alpha', 1e-5, 10, log=True),
            fit_prior=trial.suggest_categorical('fit_prior', [True, False]),
            class_prior=[0.6, 0.4]
        )
        
        # Обучение модели
        model.fit(X_train, y_train)
        
        # Оцениваем модель с помощью кросс-валидации
        return cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()
    
    sampler = optuna.samplers.RandomSampler(seed=42)
    study = optuna.create_study(sampler=sampler, direction='maximize')
    study.optimize(objective, n_trials=300)

    # Обучение модели с лучшими гиперпараметрами
    best_model = MultinomialNB(**study.best_params)
    best_model.fit(X_train, y_train)

    # Выбираем оптимальный порог отсечения
    optimal_threshold = get_best_threshold(best_model, X_train, y_train)
    y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

    # Считаем регрессионную метрику
    reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 3)

    # Выводим метрики
    print(f'Answer {i+1}:')
    print(classification_report(y_test, y_test_pred))
    print(f'MAE = {reg_score}')

    return y_test_pred

# %%
predictions = pd.DataFrame() # датафрейм с предсказаниями для ответов в каждой колонке

for i in range(N):
    cols = [f'answer{i+1}', f'answer{i+1}_len']

    # Выбираем ответ на конкретный вопрос
    X_df_tmp, y_df_tmp = X_df[cols], y_df[f'score{i+1}']
    X_train, X_test, y_train, y_test = train_test_split(X_df_tmp, y_df_tmp, stratify=y_df_tmp, test_size=0.3, random_state=42)

    # Производим векторизацию
    lens_train = X_train[f'answer{i+1}_len'].to_numpy().reshape(-1, 1) # сохраняем столбец с весами, чтобы добавить его к признакам
    lens_test = X_test[f'answer{i+1}_len'].to_numpy().reshape(-1, 1)
    X_train = np.hstack([vectorizer.fit_transform(X_train[f'answer{i+1}']).toarray(), lens_train]) # векторизация и склеивание со столбцом длин
    X_test = np.hstack([vectorizer.transform(X_test[f'answer{i+1}']).toarray(), lens_test])
    
    # непрерывные таргеты для регрессионной оценки
    y_test_cont = df.iloc[y_test.index][f'score{i+1}']

    y_pred = train_model(X_train, X_test, y_train, y_test, y_test_cont)
    predictions[f'pred_score{i+1}'] = y_pred
# Out:
# Answer 1:
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       123
#            1       0.64      0.74      0.69        73
#
#     accuracy                           0.75       196
#    macro avg       0.74      0.75      0.74       196
# weighted avg       0.76      0.75      0.75       196
#
# MAE = 0.5815229972899074
# Answer 2:
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.75        87
#            1       0.79      0.84      0.81       109
#
#     accuracy                           0.79       196
#    macro avg       0.79      0.78      0.78       196
# weighted avg       0.79      0.79      0.78       196
#
# MAE = 0.6529689771882266
# Answer 3:
#               precision    recall  f1-score   support
#
#            0       0.82      0.65      0.72        83
#            1       0.78      0.89      0.83       113
#
#     accuracy                           0.79       196
#    macro avg       0.80      0.77      0.78       196
# weighted avg       0.79      0.79      0.79       196
#
# MAE = 0.8030644199457911

# %%
(0.74 + 0.78 + 0.78) / 3   # avg f1_macro
# Out:
# 0.7666666666666666

# %%
(0.58 + 0.65 + 0.77) / 3   # avg MAE
# Out:
# 0.6666666666666666

# %% [markdown]
# Немного проигрывает аналогичному подходу с использованием логрегрессии.

# %% [markdown]
# ### 2.3.3. Одна модель на все ответы

# %%
X, y = df[['general_answer', 'answer1_len', 'answer2_len', 'answer3_len']], df['result']
y = (y >= 6).astype(int)  # сводим к классификации

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Векторизуем и добавляем признаки с длинами ответов:

# %%
# считаем длины ответов и переводим в массив numpy
lens_train = X_train[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()
lens_test = X_test[['answer1_len', 'answer2_len', 'answer3_len']].to_numpy()

# векторизуем и склеиваем с признаками длины
X_train = np.hstack([vectorizer.fit_transform(X_train['general_answer']).toarray(), lens_train])
X_test = np.hstack([vectorizer.transform(X_test['general_answer']).toarray(), lens_test])

# %%
def objective(trial): 
    model = MultinomialNB(
        alpha=trial.suggest_float('alpha', 1e-5, 10, log=True),
        fit_prior=trial.suggest_categorical('fit_prior', [True, False]),
        class_prior=[0.6, 0.4]
    )
    
    # Обучение модели
    model.fit(X_train, y_train)
    
    # Оцениваем модель с помощью кросс-валидации
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_macro').mean()

    # Выводим логи
    print(f'Trial {trial.number+1}: score = {score}')

    return score
    
sampler = optuna.samplers.RandomSampler(seed=42)
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=1000)
# Out:
# Trial 1: score = 0.5790618282868805
# Trial 2: score = 0.5552215166359495
# Trial 3: score = 0.5564378456906336
# Trial 4: score = 0.5559949291057156
# Trial 5: score = 0.5427619192606887
# Trial 6: score = 0.563978363535832
# Trial 7: score = 0.5635184978904096
# Trial 8: score = 0.563978363535832
# Trial 9: score = 0.5621909755067046
# Trial 10: score = 0.5560943347300553
# Trial 11: score = 0.555283426099608
# Trial 12: score = 0.3893920969366683
# Trial 13: score = 0.5732430813465141
# Trial 14: score = 0.5635184978904096
# Trial 15: score = 0.5601881520031752
# Trial 16: score = 0.5573885515023954
# Trial 17: score = 0.5574488954811109
# Trial 18: score = 0.5560340614294805
# Trial 19: score = 0.5552215166359495
# Trial 20: score = 0.563978363535832
# Trial 21: score = 0.5717219457956639
# Trial 22: score = 0.5752641488869921
# Trial 23: score = 0.563978363535832
# Trial 24: score = 0.3328024968672581
# Trial 25: score = 0.5543760775723056
# Trial 26: score = 0.5532314431022024
# Trial 27: score = 0.5752641488869921
# Trial 28: score = 0.5567812464659508
# Trial 29: score = 0.5732430813465141
# Trial 30: score = 0.5585770034577615
# Trial 31: score = 0.5601983671045321
# Trial 32: score = 0.5574488954811109
# Trial 33: score = 0.5559083875613517
# Trial 34: score = 0.5621104286988368
# Trial 35: score = 0.575137611840846
# Trial 36: score = 0.5707941324556816
# Trial 37: score = 0.5688874815544346
# Trial 38: score = 0.563978363535832
# Trial 39: score = 0.5585770034577615
# Trial 40: score = 0.563978363535832
# Trial 41: score = 0.5445744862423803
# Trial 42: score = 0.5621104286988368
# Trial 43: score = 0.5390145177426844
# Trial 44: score = 0.5560943347300553
# Trial 45: score = 0.5601983671045321
# Trial 46: score = 0.5733802273038066
# Trial 47: score = 0.5752641488869921
# Trial 48: score = 0.5707941324556816
# Trial 49: score = 0.5732430813465141
# Trial 50: score = 0.5504391668920585
# Trial 51: score = 0.4851391571014168
# Trial 52: score = 0.5523417798000756
# Trial 951: score = 0.5565390305383124
# Trial 952: score = 0.46921603463439665
# Trial 953: score = 0.5658904251301367
# Trial 954: score = 0.563978363535832
# Trial 955: score = 0.3858857266466168
# Trial 956: score = 0.5540296169360781
# Trial 957: score = 0.5732430813465141
# Trial 958: score = 0.38865284046896975
# Trial 959: score = 0.5504048083647562
# Trial 960: score = 0.563978363535832
# Trial 961: score = 0.5752641488869921
# Trial 962: score = 0.5538626254788692
# Trial 963: score = 0.5541822731357506
# Trial 964: score = 0.5363098757351052
# Trial 965: score = 0.550657681559237
# Trial 966: score = 0.5168347864617203
# Trial 967: score = 0.5666533393976341
# Trial 968: score = 0.5502084145479555
# Trial 969: score = 0.5559083875613517
# Trial 970: score = 0.5688874815544346
# Trial 971: score = 0.5688874815544346
# Trial 972: score = 0.3558084601996237
# Trial 973: score = 0.5593743335831969
# Trial 974: score = 0.5732430813465141
# Trial 975: score = 0.5390145177426844
# Trial 976: score = 0.49679395285071964
# Trial 977: score = 0.5590785811179818
# Trial 978: score = 0.5547206139909239
# Trial 979: score = 0.5559949291057156
# Trial 980: score = 0.552152394002517
# Trial 981: score = 0.5702097168712659
# Trial 982: score = 0.5524820586752592
# Trial 983: score = 0.5560943347300553
# Trial 984: score = 0.42625674865751606
# Trial 985: score = 0.5524820586752592
# Trial 986: score = 0.5566797954897404
# Trial 987: score = 0.5740122963271367
# Trial 988: score = 0.5752641488869921
# Trial 989: score = 0.5293302900188435
# Trial 990: score = 0.5574488954811109
# Trial 991: score = 0.5789202681748791
# Trial 992: score = 0.5513549862257455
# Trial 993: score = 0.5345037217262052
# Trial 994: score = 0.3485900572382276
# Trial 995: score = 0.5559949291057156
# Trial 996: score = 0.352247646544103
# Trial 997: score = 0.5524820586752592
# Trial 998: score = 0.5476467893146834
# Trial 999: score = 0.5601983671045321
# Trial 1000: score = 0.5732430813465141

# %%
y_test_cont = df.iloc[y_test.index]['result']   # для регрессионной модели
y_test_cont
# Out:
# 322    1.0
# 443    6.0
# 466    6.0
# 444    9.0
# 156    9.0
#       ...
# 151    3.5
# 192    6.0
# 223    3.0
# 327    6.5
# 600    1.0
# Name: result, Length: 196, dtype: float64

# %%
# Обучение модели с лучшими гиперпараметрами
best_model = MultinomialNB(**study.best_params)
best_model.fit(X_train, y_train)

# Делаем предсказания для трейна и теста
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# Выбираем оптимальный порог отсечения и делаем новые предсказания для теста
optimal_threshold = get_best_threshold(best_model, X_train, y_train)
y_test_pred = (best_model.predict_proba(X_test)[:, 1] >= optimal_threshold).astype(int)

# Регрессионная оценка
reg_score = mean_absolute_error(y_test_cont, best_model.predict_proba(X_test)[:, 1] * 9)

# %%
print(classification_report(y_test, y_test_pred))
print(f'MAE = {reg_score}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75       126
#            1       0.51      0.33      0.40        70
#
#     accuracy                           0.65       196
#    macro avg       0.60      0.58      0.58       196
# weighted avg       0.63      0.65      0.63       196
#
# MAE = 3.3346313143065727

# %% [markdown]
# Тогда на каждый ответ в средднем приходится ошибка MAE:

# %%
3.34 / 3
# Out:
# 1.1133333333333333
